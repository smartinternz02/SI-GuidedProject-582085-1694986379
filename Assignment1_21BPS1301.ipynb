# %%
#task1
import numpy as np
import pandas as pd

num_observations = 4
num_features = 4

random_values = np.random.rand(num_observations, num_features)

column_names = ['F1', 'F2', 'F3', 'F4']
df = pd.DataFrame(random_values, columns=column_names)
df
# Out:
#          F1        F2        F3        F4
# 0  0.967379  0.733241  0.829978  0.922334
# 1  0.128129  0.866393  0.687130  0.827673
# 2  0.683344  0.966409  0.069626  0.366002
# 3  0.116825  0.931416  0.135206  0.225193

# %%
#task2
df.rename({'F1': 'Random value 1', 'F2': 'Random value 2', 'F3': 'Random value 3', 'F4': 'Random value 4'}, axis=1, inplace=True)
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.967379        0.733241        0.829978        0.922334
# 1        0.128129        0.866393        0.687130        0.827673
# 2        0.683344        0.966409        0.069626        0.366002
# 3        0.116825        0.931416        0.135206        0.225193

# %%
#task3
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.473919        0.874365        0.430485        0.585301
# std          0.422078        0.102805        0.384218        0.341617
# min          0.116825        0.733241        0.069626        0.225193
# 25%          0.125303        0.833105        0.118811        0.330800
# 50%          0.405737        0.898905        0.411168        0.596838
# 75%          0.754353        0.940164        0.722842        0.851339
# max          0.967379        0.966409        0.829978        0.922334

# %%
#task4
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random value 1  4 non-null      float64
#  1   Random value 2  4 non-null      float64
#  2   Random value 3  4 non-null      float64
#  3   Random value 4  4 non-null      float64
# dtypes: float64(4)
# memory usage: 256.0 bytes
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %%
#task5
df['Random value 2']
# Out:
# 0    0.733241
# 1    0.866393
# 2    0.966409
# 3    0.931416
# Name: Random value 2, dtype: float64

# %%
#task5
df['Random value 3']
# Out:
# 0    0.829978
# 1    0.687130
# 2    0.069626
# 3    0.135206
# Name: Random value 3, dtype: float64

# %%
#task5
df.iloc[:, 1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.733241        0.829978
# 1        0.866393        0.687130
# 2        0.966409        0.069626
# 3        0.931416        0.135206
